# %%
import requests
url = "https://imdb8.p.rapidapi.com/title/get-filming-locations"
querystring = {"tconst":"tt0944947"}

headers = {
    'x-rapidapi-host': "imdb8.p.rapidapi.com",
    'x-rapidapi-key': "9350bfab27msh4998184b390aa1dp129073jsn9f8270cbfc0e"
    }

# %%
response = requests.request("GET", url, headers=headers, params=querystring)
print(response.text)
# Out:
# {"@type":"imdb.api.title.filminglocations","base":{"id":"/title/tt0944947/","image":{"height":1500,"id":"/title/tt0944947/images/rm4204167425","url":"https://m.media-amazon.com/images/M/MV5BYTRiNDQwYzAtMzVlZS00NTI5LWJjYjUtMzkwNTUzMWMxZTllXkEyXkFqcGdeQXVyNDIzMzcwNjc@._V1_.jpg","width":1102},"runningTimeInMinutes":57,"nextEpisode":"/title/tt1480055/","numberOfEpisodes":73,"seriesEndYear":2019,"seriesStartYear":2011,"title":"Game of Thrones","titleType":"tvSeries","year":2011},"id":"/title/tt0944947/","locations":[{"id":"/title/tt0944947/filminglocations/lc0820830","interestingVotes":{"down":10,"up":359},"location":"Split, Split-Dalmatia County, Croatia"},{"id":"/title/tt0944947/filminglocations/lc0820831","interestingVotes":{"down":8,"up":212},"location":"Vrsno, Sibenik, Croatia"},{"id":"/title/tt0944947/filminglocations/lc0449596","interestingVotes":{"down":21,"up":423},"location":"Dubrovnik, Croatia"},{"id":"/title/tt0944947/filminglocations/lc0449602","interestingVotes":{"down":8,"u
# ...

# %%
import pandas as pd
import numpy as np

# %%
df_response = pd.DataFrame( response )
df_response
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-c0729e0ab00e> in <module>()
# ----> 1 df_response = pd.to_json( response )
#       2 df_response
#
# AttributeError: module 'pandas' has no attribute 'to_json'

# %%
# Out:
#                                                     0
# 0   b'{"@type":"imdb.api.title.filminglocations","...
# 1   b'/rm4204167425","url":"https://m.media-amazon...
# 2   b'IzMzcwNjc@._V1_.jpg","width":1102},"runningT...
# 3   b'ear":2019,"seriesStartYear":2011,"title":"Ga...
# 4   b'ns":[{"id":"/title/tt0944947/filminglocation...
# ..                                                ...
# 61  b'ing\'s Landing"],"id":"/title/tt0944947/film...
# 62  b'azanas de Sevilla, Sevilla, Sevilla, Andaluc...
# 63  b'947/filminglocations/lc1863779","interesting...
# 64  b'tras":["Daenerys brings Jorah Mormont back t...
# 65  b'c1998246","location":"Sierra de Caldereros, ...
#
# [66 rows x 1 columns]

# %%
import json

# %%
url = "http://www.omdbapi.com/?i=tt3896198&apikey=df20d6f5/?t=scream"

# %%
response = requests.get(url)
python_dictionary_values = json.loads(response.text)

# %%
python_dictionary_values
# Out:
# {'Error': 'Invalid API key!', 'Response': 'False'}

# %%
# !pip install imdbpy
# Out:
# ...
#      |████████████████████████████████| 296kB 2.6MB/s
# ...

# %%
import imdb
from imdb import IMDb

# %%
moviesDB = imdb.IMDb()

# %%
dir( moviesDB )
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_defModFunct',
#  '_getRefs',
#  '_get_infoset',
#  '_get_keyword',
#  '_get_real_characterID',
#  '_get_real_companyID',
#  '_get_real_movieID',
#  '_get_real_personID',
#  '_get_search_content',
#  '_get_search_movie_advanced_content',
#  '_get_top_bottom_movies',
#  '_http_logger',
#  '_keywordsResults',
#  '_mdparse',
#  '_normalize_characterID',
#  '_normalize_companyID',
#  '_normalize_movieID',
#  '_normalize_personID',
#  '_purge_seasons_data',
#  '_reraise_exceptions',
#  '_results',
#  '_retrieve',
#  '_searchIMDb',
#  '_search_character',
# ...

# %%
movies = moviesDB.get_movie_locations( movieID = '1375666')
movies['data']['locations']
# Out:
# ['Tangier, Morocco::(as Mombasa, Kenya)',
#  'Fortress Mountain, Kananaskis Country, Alberta, Canada',
#  'Shizuoka, Japan',
#  'Tokyo, Japan',
#  'Da Stuzzi Delicatessen, 6 Rue César Franck, Paris 15, France::(as Café Debussy)',
#  'Alberta, Canada',
#  'Pont de Bir-Hakeim, Paris, France',
#  'Spring Street, Downtown, Los Angeles, California, USA',
#  'Bedford, Bedfordshire, England, UK',
#  'Kananaskis Village, Kananaskis Country, Alberta, Canada',
#  'Cardington Airship Hangars, Bedfordshire, England, UK::(studio)',
#  'Morocco',
#  'Commodore Schuyler F. Heim Bridge, Port of Los Angeles, Los Angeles, California, USA::(van falling from bridge)',
#  'University College London, Bloomsbury, London, England, UK',
#  'Farnborough Airfield, Hampshire, England, UK',
#  'Rancho Palos Verdes, California, USA',
#  'Rue Bouchut, Paris 15, Paris, France',
#  'Bedfordshire, England, UK',
#  'John Ferraro Building, 111 North Hope Street, Los Angeles, California, USA',
# ...

# %%
moviesDB

# %%
import re

# %%
movies_for_testing = moviesDB.search_movie('julio')
movies_for_testing
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-57-585cfa043ea6> in <module>()
#       1 movies_for_testing = moviesDB.search_movie('julio')
# ----> 2 movies_for_testing.get_real_movieID
#
# AttributeError: 'list' object has no attribute 'get_real_movieID'

# %%
ia = IMDb()
movie = ia.get_movie('1271280')
movie
# Out:
# <Movie id:1271280[http] title:_"Coronation Street" Episode #1.4160 (1997)_>

# %%
for genre in movie['genres']:
    print(genre)
# Out:
# Drama
# Romance

# %%
for genre in movie['MoveID']:
    print(genre)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-c60158dece82> in <module>()
# ----> 1 for genre in movie[0]:
#       2     print(genre)
#
# /usr/local/lib/python3.6/dist-packages/imdb/utils.py in __getitem__(self, key)
#    1502         # Handle key aliases.
#    1503         key = self.keys_alias.get(key, key)
# -> 1504         rawData = self.data[key]
#    1505         if key in self.keys_tomodify and \
#    1506                 self.modFunct not in (None, modNull):
#
# KeyError: 0
